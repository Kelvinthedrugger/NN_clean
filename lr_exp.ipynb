# %%
from lr_finder import lr_example

# %%
train, test ,lrs = lr_example()
# Out:
# loss being too large, exit
# loss: 0.3756, val_loss: 2.2624

# %%
round(min(train["loss"]),3) , lrs[train["loss"].index(min(train["loss"]))]
# Out:
# (0.247, 1.0699320537907193e-06)

# %% [markdown]
# # Calculate lr_min, lr_max not done

# %%
# build model again to train using the learning rate
